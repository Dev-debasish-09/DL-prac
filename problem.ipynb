# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-debasish-09/DL-prac/blob/main/problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input1'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input1'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
sns.scatterplot(x='input1',y='input2',data=or_data,hue='output')
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x='input1',y='input2',data=and_data,hue='output')
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x='input1',y='input2',data=xor_data,hue='output')
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
p1 = Perceptron()
p2 = Perceptron()
p3 = Perceptron()

# %%
p1.fit(or_data[['input1','input2']],or_data['output'])
# Out:
# Perceptron()

# %%
p2.fit(and_data[['input1','input2']],and_data['output'])
# Out:
# Perceptron()

# %%
p3.fit(xor_data[['input1','input2']],xor_data['output'])
# Out:
# Perceptron()

# %%
x = np.linspace(-1,1,5)
y =- x+1

# %%
plt.plot(x,y)
sns.scatterplot(x='input1',y='input2',data=or_data,hue='output')
# Out:
# <Axes: xlabel='input1', ylabel='input2'>
